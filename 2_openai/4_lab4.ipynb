# %% [markdown]
# ## Deep Research
#
# One of the classic cross-business Agentic use cases! This is huge.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">A Deep Research agent is broadly applicable to any business area, and to your own day-to-day activities. You can make use of this yourself!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from agents import Agent, WebSearchTool, trace, Runner, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
from IPython.display import display, Markdown
from messenger import send_email, push

# %%
load_dotenv(override=True)
# Out:
# True

# %%
# Constants 

MODEL_NAME = "gpt-5.4-mini"
USE_EMAIL = True
HOW_MANY_SEARCHES = 5 # how many web searches, see later

# %% [markdown]
# ## Strategy for the Deep Research Agent
#
# We are going to do it the bulletproof way.
#
# We are going to orchestrate with code: separate calls to `Runner.run()` for each step in the process.
#
# We will use Structured Outputs at each point.
#
# ## We will build 4 Agents:
#
# 1. The Search Agent: searches the web for information
# 2. The Planner Agent: given a question, comes up with a list of searches that should be made
# 3. The Writer Agent: writes a robust report
# 4. The Emailer Agent: crafts and sends an email
#
# And then 4 python functions, 1 to call Runner.run() for each of the 4 agents.

# %% [markdown]
# ## Agent 1: The Search Agent

# %% [markdown]
# ### OpenAI Hosted Tools
#
# https://openai.github.io/openai-agents-python/tools/#hosted-tools
#
# A paid, quick approach to carrying out managed functionality on OpenAI's cloud.
#
# Their docs surface these tools, but it's worth keeping in mind that they're costly and lock you in to the OpenAI ecosystem.
#
# OpenAI offers the following hosted tools:
#
# `WebSearchTool` lets an agent search the web.
# `FileSearchTool` allows retrieving information from your OpenAI Vector Stores.
# `CodeInterpreterTool` lets the LLM execute code in a sandboxed environment.
# `HostedMCPTool` exposes a remote MCP server's tools to the model.
# `ImageGenerationTool` generates images from a prompt.
# `ToolSearchTool` lets the model load deferred tools, namespaces, or hosted MCP servers on demand.
#
# ### Important note - API charge of WebSearchTool
#
# This currently costs 1 cent per call for OpenAI WebSearchTool. That can add up to about $1 for the next 2 labs. We'll use free and low cost Search tools with other platforms, so feel free to skip running this if the cost is a concern. Also student Christian W. pointed out that OpenAI can sometimes charge for multiple searches for a single call, so it could sometimes cost more than 1 cent per call.
#
# Costs are in the Tools section here: https://developers.openai.com/api/docs/pricing

# %%
INSTRUCTIONS = """
You are a research assistant. Given a search term, you search the web for that term and 
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words.
Capture the main points and be succinct. Reply only with the summary.
"""
task = "Most popular AI Agent frameworks in 2026"

settings = ModelSettings(tool_choice="required")
tools = [WebSearchTool()]

# %%
search_agent = Agent(name="Search Agent", instructions=INSTRUCTIONS, tools=tools, model=MODEL_NAME, model_settings=settings)

# %%
result = await Runner.run(search_agent, task)
display(Markdown(result.final_output))
# Out:
# In 2026, the most commonly cited AI agent frameworks are **LangChain/LangGraph, CrewAI, AutoGen (and AG2), Pydantic AI, Semantic Kernel, Haystack, Agno, and OpenAI’s Agents SDK**. Across curated 2026 lists, **LangChain** is still the broadest and most widely adopted general-purpose LLM framework, while **LangGraph** is frequently highlighted for stateful, production-grade agent workflows. **CrewAI** and **AutoGen** remain the main names in multi-agent orchestration, with **Pydantic AI** gaining traction for type-safe Python agent development. ([github.com](https://github.com/vishwasvijayabaskar-code/awesome-ai-agents?utm_source=openai))
#
# If you look specifically at “most popular” by GitHub-star–style popularity, recent curated rankings often place **LangChain, AutoGen, Dify, CrewAI, LangGraph, and LlamaIndex** near the top, though the exact order varies by list and date. A 2026 multi-agent ranking also shows strong momentum for newer orchestration projects like **deer-flow**, alongside **MetaGPT, AutoGen, CrewAI, LangGraph, and AgentScope**. In practice, the best choice depends on the use case: **LangGraph** for reliable workflow control, **CrewAI** for role-based multi-agent teams, **AutoGen** for conversational multi-agent systems, and **Pydantic AI** for strict Python typing and cleaner app integration. ([github.com](https://github.com/wind8ai/multi-agent-top-stars/blob/main/README.en.md?utm_source=openai))

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Agent 2: The Planner Agent

# %% [markdown]
# ### We will now use Structured Outputs, and include a description of the fields

# %%
class WebSearchItem(BaseModel): # Put it in this order, as putting reason first often yields better results
    reason: str = Field(description="Your reasoning for why this search is important to the query.")
    query: str = Field(description="The search term to use for the web search.")


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem] = Field(description="A list of web searches to perform to best answer the query.")

# %%
WebSearchPlan.model_json_schema()
# Out:
# {'$defs': {'WebSearchItem': {'properties': {'reason': {'description': 'Your reasoning for why this search is important to the query.',
#      'title': 'Reason',
#      'type': 'string'},
#     'query': {'description': 'The search term to use for the web search.',
#      'title': 'Query',
#      'type': 'string'}},
#    'required': ['reason', 'query'],
#    'title': 'WebSearchItem',
#    'type': 'object'}},
#  'properties': {'searches': {'description': 'A list of web searches to perform to best answer the query.',
#    'items': {'$ref': '#/$defs/WebSearchItem'},
#    'title': 'Searches',
#    'type': 'array'}},
#  'required': ['searches'],
#  'title': 'WebSearchPlan',
#  'type': 'object'}

# %%
# See note above about cost of WebSearchTool

INSTRUCTIONS = f"""
You are a research assistant. Given a user query, come up with a set of web searches
to perform to best answer the query. Output {HOW_MANY_SEARCHES} terms to query for.
"""

planner_agent = Agent(name="Planner Agent", instructions=INSTRUCTIONS, model=MODEL_NAME, output_type=WebSearchPlan)

# %%
result = await Runner.run(planner_agent, task)
result.final_output
# Out:
# WebSearchPlan(searches=[WebSearchItem(reason='Find current comparisons and rankings of AI agent frameworks expected to be popular in 2026, including market adoption and trend analyses.', query='most popular AI agent frameworks 2026 comparison ranking'), WebSearchItem(reason='Check recent industry articles and developer surveys that mention which agent frameworks are gaining traction for 2026.', query='AI agent framework trends developer survey 2025 2026'), WebSearchItem(reason='Identify major open-source and commercial frameworks likely to dominate in 2026 and their feature sets.', query='top AI agent frameworks open source commercial 2026'), WebSearchItem(reason='Look for benchmark or evaluation articles comparing framework capabilities, ecosystem, and community adoption.', query='AI agent framework benchmark LangGraph CrewAI AutoGen Semantic Kernel 2026'), WebSearchItem(reason='Capture updates from official documentation and release notes for leading frameworks to ensure the latest status.', query='official documentation release notes AI agent frameworks LangGraph CrewAI AutoGen Semantic Kernel')])

# %% [markdown]
# ## Agent 3: The Writer Agent

# %%
INSTRUCTIONS = """
You are a senior researcher tasked with writing a cohesive report for a research query.
You will be provided with the original query, and some research.
Generate a comprehensive report based on the research and the query. Provide detailed rationale behind results, 
NOT just a summary of results. 
The final output should be in markdown format, and it should be lengthy and detailed. Aim 
for 5-10 pages of content, at least 1000 words.
"""


class ReportData(BaseModel):
    short_summary: str = Field(description="A short 2-3 sentence summary of the findings.")
    markdown_report: str = Field(description="The final report")
    follow_up_questions: list[str] = Field(description="Suggested topics to research further")


writer_agent = Agent(name="Writer Agent", instructions=INSTRUCTIONS, model=MODEL_NAME, output_type=ReportData)

# %%
result = await Runner.run(writer_agent, task)
result.final_output
# Out:
# ReportData(short_summary='The most popular AI agent frameworks in 2026 are likely to be a mix of mature orchestration libraries, cloud-provider toolkits, and emerging multi-agent platforms. The market is still fluid, but frameworks that emphasize tool use, memory, workflow orchestration, evaluation, and production deployment are standing out as the most adopted.', markdown_report='# Most Popular AI Agent Frameworks in 2026\n\n## Executive overview\n\nAI agent frameworks have moved from experimental developer tools to an important layer in the modern AI stack. By 2026, the category is no longer defined only by “agents” in the narrow sense of autonomous LLM loops. Instead, it includes a broader ecosystem of frameworks for tool-using assistants, workflow orchestration, multi-agent collaboration, memory management, retrieval, guardrails, and production monitoring.\n\nThe most popular frameworks in 2026 are those that solve one or more of the following problems well:\n\n- connecting models to tools and APIs\n- orchestrating multi-step workflows\n- supporting multi-agent or role-based systems\n- handling memory, state, and retrieval\n- making evaluation, tracing, and debugging practical\n- simplifying deployment in production environments\n\nPopularity is also increasingly split across two dimensions:\n\n1. **Developer mindshare** — what people prototype with.\n2. **Production adoption** — what teams actually ship and operate.\n\nIn 2026, the top frameworks are generally those that are either:\n\n- mature and widely adopted across enterprises,\n- tightly integrated with major model providers,\n- easy to adopt in Python/TypeScript ecosystems, or\n- strong in observability, workflows, and agent control.\n\n## What counts as an “AI agent framework” in 2026?\n\nThe term “agent framework” has become broader than it was in the early wave of LLM tooling. In practice, the category now includes:\n\n- **agent orchestration frameworks** — systems that manage prompts, tool calls, and iterative reasoning loops\n- **workflow frameworks** — systems that treat agent behavior as stateful graphs or DAGs rather than free-form loops\n- **multi-agent frameworks** — systems for coordinating several specialized agents\n- **enterprise agent platforms** — managed environments with connectors, governance, and deployment tooling\n- **developer libraries** — flexible open-source packages for custom agent logic\n\nThis matters because “most popular” may not mean the same thing for every audience. A startup developer might prefer a lightweight library; an enterprise might prefer a managed platform with tracing and policy controls.\n\n## Most popular AI agent frameworks in 2026\n\nBelow is a practical ranking of the frameworks most likely to be considered the leading choices in 2026, based on ecosystem momentum, breadth of use cases, and relevance to production-grade agent systems.\n\n### 1. LangChain\n\nLangChain remains one of the most recognizable names in the agent framework space. Even as the ecosystem has diversified, LangChain has retained strong mindshare because it is broad, flexible, and deeply integrated into the LLM application development workflow.\n\n#### Why it remains popular\n\n- Large developer community and ecosystem\n- Rich set of integrations for tools, retrievers, vector databases, and models\n- Strong support for agentic patterns and tool use\n- Works well as a foundation layer for custom applications\n- Closely associated with the growth of LLM app development overall\n\n#### Strengths\n\nLangChain is often chosen because it offers a broad abstraction layer for building LLM-based applications. Teams can prototype quickly, then extend toward more complex agent behavior.\n\nIt is especially attractive when developers need:\n\n- many integrations\n- flexible prompt/tool pipelines\n- compatibility with other AI infrastructure\n- support for both experimentation and production\n\n#### Limitations\n\nIts breadth can also be a drawback. Some deve ...

# %% [markdown]
# ## Agent 4: The email agent

# %%
@function_tool # Decorator
def send_email_tool(subject: str, text_body: str, html_body: str) -> str:
    """
    Send out an email with the given subject and body to all sales prospects
    
    Args:
        subject: The subject of the email
        text_body: The body of the email as plain text
        html_body: The HTML body of the email
    """
    if USE_EMAIL:
        send_email(subject, text_body, html_body)
    else:
        push(f"Subject: {subject}\n\n{text_body}")
    return "Email sent successfully"

# %%
send_email_tool.params_json_schema
# Out:
# {'properties': {'subject': {'description': 'The subject of the email',
#    'title': 'Subject',
#    'type': 'string'},
#   'text_body': {'description': 'The body of the email as plain text',
#    'title': 'Text Body',
#    'type': 'string'},
#   'html_body': {'description': 'The HTML body of the email',
#    'title': 'Html Body',
#    'type': 'string'}},
#  'required': ['subject', 'text_body', 'html_body'],
#  'title': 'send_email_tool_args',
#  'type': 'object',
#  'additionalProperties': False}

# %%
INSTRUCTIONS = """
You are provided with a detailed report. Use your tool to send an email, converting the report into
a clean, well presented HTML email with an appropriate subject line.
"""

email_agent = Agent(name="Email Agent", instructions=INSTRUCTIONS, tools=[send_email_tool], model=MODEL_NAME)

# %% [markdown]
# ## Now to Orchestrate by Code
#
# The next 2 functions will plan and execute the search, using the Agents, with calls to `Runner.run()`

# %%
async def run_searches(query: str):
    print("Planning searches...")
    result = await Runner.run(planner_agent, f"Query: {query}")
    searches = result.final_output.searches
    print(f"Will perform {len(searches)} searches")
    tasks = [search(item) for item in searches]
    results = await asyncio.gather(*tasks)
    print("Finished searching")
    return results


async def search(item: WebSearchItem):
    input_message = f"Search term: {item.query}\nReason for searching: {item.reason}"
    result = await Runner.run(search_agent, input_message)
    return result.final_output

# %% [markdown]
# The next 2 functions write a report and email it

# %%
async def write_report(query: str, search_results: list[str]):
    print("Thinking about report...")
    input_message = f"Original query: {query}\nSummarized search results: {search_results}"
    result = await Runner.run(writer_agent, input_message)
    print("Finished writing report")
    return result.final_output

async def send_report_email(report: ReportData):
    print("Writing email...")
    result = await Runner.run(email_agent, report.markdown_report)
    print("Email sent")
    return result.final_output

# %% [markdown]
# ### Showtime!

# %%
#query ="Most popular AI Agent frameworks in 2026"
query="Best 2-day per week 90 minute full-body weight-training routines for an experienced lifter over 50. Prioritize muscle maintenance, then hypertrophy as a secondary focus.Include set, rep range and weight progression."

with trace("Research trace"):
    print("Starting research...")
    search_results = await run_searches(query)
    report = await write_report(query, search_results)
    await send_report_email(report)  
    print("Hooray!")
# Out:
# Starting research...
# Planning searches...
# Will perform 5 searches
# Finished searching
# Thinking about report...
# Finished writing report
# Writing email...
# Email sent
# Hooray!

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thanks.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00cc00;">Congratulations on your progress, and a request</h2>
#             <span style="color:#00cc00;">You've reached an important moment with the course; you've created a valuable Agent using one of the latest Agent frameworks. You've upskilled, and unlocked new commercial possibilities. Take a moment to celebrate your success!<br/><br/>Something I should ask you -- my editor would smack me if I didn't mention this. If you're able to rate the course on Udemy, I'd be seriously grateful: it's the most important way that Udemy decides whether to show the course to others and it makes a massive difference.<br/><br/>And another reminder to <a href="https://www.linkedin.com/in/eddonner/">connect with me on LinkedIn</a> if you wish! If you wanted to post about your progress on the course, please tag me and I'll weigh in to increase your exposure.
#             </span>
#         </td>
#     </tr>
