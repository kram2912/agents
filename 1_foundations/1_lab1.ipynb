# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
#print(response)
print(response.choices[0].message.content)
# Out:
# 2 + 2 is 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If five machines take five minutes to make five widgets, how long would 100 machines take to make 100 widgets?

# %%
# form a new messages list
print(question)
messages = [{"role": "user", "content": question}]
# Out:
# If five machines take five minutes to make five widgets, how long would 100 machines take to make 100 widgets?

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step:
#
# - **Given:** 5 machines take 5 minutes to make 5 widgets.
#
#   This means that 5 machines produce 5 widgets in 5 minutes.
#
# - **Step 1:** Find the rate of one machine.
#
# Since 5 machines make 5 widgets in 5 minutes, the rate per machine is:
#
# \[
# \frac{5 \text{ widgets}}{5 \text{ machines} \times 5 \text{ minutes}} = \frac{5}{25} = \frac{1}{5} \text{ widgets per minute per machine}
# \]
#
# So, each machine makes \( \frac{1}{5} \) widgets per minute (or 1 widget in 5 minutes).
#
# - **Step 2:** Calculate how long 100 machines take to make 100 widgets.
#
# Each machine makes 1 widget in 5 minutes. So,
#
# - 100 machines make 100 widgets in 5 minutes.
#
# **Answer:** It would take **5 minutes** for 100 machines to make 100 widgets.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step:
#
# - **Given:** 5 machines take 5 minutes to make 5 widgets.
#
#   This means that 5 machines produce 5 widgets in 5 minutes.
#
# - **Step 1:** Find the rate of one machine.
#
# Since 5 machines make 5 widgets in 5 minutes, the rate per machine is:
#
# \[
# \frac{5 \text{ widgets}}{5 \text{ machines} \times 5 \text{ minutes}} = \frac{5}{25} = \frac{1}{5} \text{ widgets per minute per machine}
# \]
#
# So, each machine makes \( \frac{1}{5} \) widgets per minute (or 1 widget in 5 minutes).
#
# - **Step 2:** Calculate how long 100 machines take to make 100 widgets.
#
# Each machine makes 1 widget in 5 minutes. So,
#
# - 100 machines make 100 widgets in 5 minutes.
#
# **Answer:** It would take **5 minutes** for 100 machines to make 100 widgets.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:
question = "Please pick a specific business area that might be worth exploring for an Agentic AI opportunity. Respond only with the answer."
messages = [{"role": "user", "content": question}]

# Then make the first call:
 
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# Then read the business idea:

question = f"Please present a common pain-point in the business areas of {answer} business area that might be worth exploring for an Agentic AI opportunity. Respond only with the answer."
messages = [{"role": "user", "content": question}]
#business_idea = response.
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message

question = f"In the business areas of {answer} where a good opportunity for Agentic AI is {business_idea}, propose an Agentic AI solution that a business should first consider."
messages = [{"role": "user", "content": question}]
#business_idea = response.
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

business_proposal = response.choices[0].message.content
print(business_proposal)
# Out:
# Supply chain optimization.
# A common pain-point in supply chain optimization is real-time demand forecasting and dynamic inventory management, where inaccurate predictions lead to stockouts or overstock, resulting in increased costs and lost sales. An Agentic AI opportunity lies in developing autonomous systems that continuously analyze diverse data sources and proactively adjust supply chain decisions to optimize inventory levels and logistics in real time.
# **Proposed Agentic AI Solution: Autonomous Real-Time Demand and Inventory Optimization Agent**
#
# ---
#
# ### **Overview**
#
# Develop an autonomous AI agent designed to **continuously monitor, predict, and optimize supply chain operations**, specifically focusing on real-time demand forecasting and dynamic inventory management. The agent integrates diverse data sources and autonomously executes adjustments to inventory levels and logistics without requiring constant human intervention, reducing errors and inefficiencies.
#
# ---
#
# ### **Key Features**
#
# 1. **Multi-source Real-Time Data Integration**
#    - Pulls data from POS systems, ERP, market trends, social media sentiment, weather forecasts, and competitor pricing.
#    - Monitors internal factors like current inventory, supplier lead times, production schedules, and logistics constraints.
#
# 2. **Dynamic Demand Forecasting**
#    - Uses advanced machine learning models (e.g., temporal convolutional networks, transformers) to predict short- and medium-term demand dynamically.
#    - Continuously retrains and adapts models based on new data and detected anomalies.
#
# 3. **Proactive Inventory Management**
#    - Determines optimal inventory levels considering demand forecasts, supplier reliability, and holding costs.
#    - Automatically triggers purchase orders or reallocations within warehouses to prevent stockouts or overstocks.
#
# 4. **Autonomous Decision Execution with Human-in-the-Loop Option**
#    - Automatically carries out supply chain decisions such as adjusting order quantities, rerouting shipments, and reprioritizing supplier contracts.
#    - Provides explanations and confidence scores alongside decisions.
#    - Includes thresholds or scenarios where human approval is required, ensuring governance and trust.
#
# 5. **Scenario Simulation and Risk Mitigation**
#    - Runs “what-if” simulations autonomously to test the impact of potential events (e.g., supplier delays, demand spikes).
#    - Adjusts strategies dynamically to mitigate risks before issues occur.
#
# ---
#
# ### **Benefits**
#
# - **Cost Reduction:** Minimize costs from excess inventory and emergency procurement.
# - **Sales Uplift:** Prevent lost sales from stockouts via accurate and responsive replenishment.
# - **Operational Efficiency:** Reduce manual forecasting effort and reactive decision-making.
# - **Agility:** Adapt quickly to market changes, promotions, or disruptions.
#
# ---
#
# ### **Initial Implementation Considerations**
#
# - Start with a **pilot focusing on a select product category or region** with sufficient data availability.
# - Integrate the agent with existing supply chain management and ERP systems.
# - Involve supply chain experts in model validation and system tuning.
# - Establish clear KPIs: forecast accuracy, inventory turnover, fulfillment rate, and cost savings.
#
# ---
#
# ### **Summary**
#
# A business should first consider deploying an **Autonomous Real-Time Demand and Inventory Optimization Agent** that acts proactively to refine forecasting and inventory decisions by synthesizing broad and dynamic data streams. This agentic AI solution directly addresses the pain points of inaccurate demand predictions and inventory imbalances by enabling **continuous, autonomous, and adaptive supply chain optimization**.

# %%
question = "In the Automative Insurance Industry in the US, and specifically focusing on Insurance Claims Subrogation processes, list out some good opportuinities for Agentic AI, highlighting the key benefits of each as well as relative complexity to achieve."
messages = [{"role": "user", "content": question}]
#business_idea = response.
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

business_proposal = response.choices[0].message.content
print(business_proposal)
# Out:
# Certainly! In the U.S. Automotive Insurance Industry, particularly within the **Insurance Claims Subrogation** process, there are several promising opportunities for deploying **Agentic AI** (i.e., AI systems capable of autonomous decision-making and action-taking). Below is a list of key opportunities, highlighting the benefits and the relative complexity of implementation for each:
#
# ---
#
# ### 1. Automated Initial Liability Assessment
# **Description:**
# AI agents autonomously analyze accident reports, police records, witness statements, and photos to determine preliminary liability shares among involved parties.
#
# **Key Benefits:**
# - Speeds up the subrogation process by quickly identifying liable parties
# - Reduces manual effort and human bias in preliminary assessments
# - Enables faster communication to third parties and legal teams
#
# **Relative Complexity:**
# **Medium to High**
# - Requires integration of diverse data sources (structured and unstructured data)
# - Natural language processing (NLP) for text analysis, computer vision for image analysis
# - Needs well-trained models and domain-specific rules to ensure accuracy and legal compliance
#
# ---
#
# ### 2. Automated Demand Letter Generation and Follow-up
# **Description:**
# Agentic AI autonomously drafts, sends, and monitors demand letters to at-fault insurers or third parties, including customized legal language based on claim specifics.
#
# **Key Benefits:**
# - Reduces turnaround times for subrogation outreach
# - Improves consistency and personalization of communications
# - Tracks responses automatically and escalates delays or denials
#
# **Relative Complexity:**
# **Medium**
# - Requires NLP for document generation and understanding of legal verbiage
# - Workflow automation to handle follow-ups and reminders
# - Integration with claims management systems for case data
#
# ---
#
# ### 3. Predictive Subrogation Outcome Modeling
# **Description:**
# AI agents analyze historical subrogation cases to predict the likelihood of recovery, expected payout amounts, and optimal negotiation strategies.
#
# **Key Benefits:**
# - Prioritizes cases with high recovery potential, improving operational efficiency
# - Assists human adjusters in making informed settlement decisions
# - Can help optimize legal spend by avoiding low-probability cases
#
# **Relative Complexity:**
# **High**
# - Requires extensive, high-quality historical claims data
# - Advanced machine learning models for predictive analytics
# - Needs continuous retraining to adapt to changing legal and market environments
#
# ---
#
# ### 4. Automated Evidence Collection and Validation
# **Description:**
# AI agents autonomously collect and validate evidence relevant for subrogation, such as medical reports, repair estimates, CCTV footage, and telematics data.
#
# **Key Benefits:**
# - Speeds up evidence gathering by interfacing with external data sources and APIs
# - Ensures evidence completeness and authenticity verification
# - Reduces human workload and errors in evidence management
#
# **Relative Complexity:**
# **High**
# - Requires API integrations with multiple external systems (hospitals, repair shops, law enforcement, telematics providers)
# - Computer vision and data validation algorithms needed
# - Legal compliance for data privacy and security critical
#
# ---
#
# ### 5. Intelligent Negotiation Agents for Recovery Settlements
# **Description:**
# Agentic AI autonomously negotiates settlements with third-party insurers or responsible parties using predefined rules, risk tolerance, and predictive models.
#
# **Key Benefits:**
# - Reduces negotiation cycle time and manual intervention
# - Enables 24/7 negotiation capabilities
# - Can optimize settlement amounts by dynamically adjusting offer strategies
#
# **Relative Complexity:**
# **Very High**
# - Requires sophisticated reinforcement learning or game theory models
# - Needs strict guardrails and oversight to comply with regulatory and ethical standards
# - Potential legal risks require clear audit trails and human override capability
#
# ---
#
# ### 6. Fraud Detection in Subrogation Claims
# **Description:**
# Agentic AI proactively flags suspicious subrogation claims or evidence, identifying potential fraud or misrepresentation by third parties.
#
# **Key Benefits:**
# - Protects against fraudulent claims, saving millions in false payouts
# - Increases accuracy of fraud detection beyond traditional rule-based systems
# - Streamlines the referral of suspicious cases to specialized investigators
#
# **Relative Complexity:**
# **Medium**
# - Relies on machine learning models trained on historical fraud and non-fraud cases
# - Integrates anomaly detection, pattern recognition, and NLP for textual clues
# - Needs constant updating with new fraud trends
#
# ---
#
# ### Summary Table
#
# | Opportunity                           | Key Benefits                                               | Relative Complexity |
# |-------------------------------------|------------------------------------------------------------|---------------------|
# | Automated Initial Liability Assessment | Fast liability determination; reduces manual bias         | Medium - High       |
# | Automated Demand Letter & Follow-up | Faster outreach; consistent legal communication             | Medium              |
# | Predictive Subrogation Outcome Modeling | Prioritizes high-value cases; informed settlement strategy  | High                |
# | Automated Evidence Collection & Validation | Speeds evidence gathering; ensures authenticity             | High                |
# | Intelligent Negotiation Agents       | 24/7 negotiation; optimized settlements                     | Very High           |
# | Fraud Detection in Subrogation Claims | Early fraud detection; reduces false payouts                | Medium              |
#
# ---
#
# ### Final Note:
# Agentic AI implementations in subrogation must be designed carefully to maintain regulatory compliance (e.g., Fair Claims Settlement Practices), preserve data privacy, and ensure clear human oversight, especially for high-stakes actions like negotiation and liability determination.
#
# If you'd like, I can help detail the technology stack, risk mitigations, or example vendor solutions related to any specific opportunity.
